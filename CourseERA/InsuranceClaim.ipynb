# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./insurance.csv', sep=',')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
len(df)
# Out:
# 1338

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.drop(df.columns[[5]], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
df.describe().transpose()
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
def fillNA(data):
    data = np.array(data)
    toFloat = [float(floatValue) for floatValue in data]       
    biggestId = np.max(toFloat)                                
    print("Max id number available =", biggestId)
    
    for i in range (len(data)):
        if float(data[i]) == 0:
            data[i] = biggestId   
            biggestId = biggestId +1                           
    return data

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# charges     0
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 18    69
# 19    68
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 20    29
# 26    28
# 54    28
# 53    28
# 25    28
# 24    28
# 49    28
# 23    28
# 22    28
# 21    28
# 27    28
# 28    28
# 31    27
# 29    27
# 30    27
# 41    27
# 43    27
# 44    27
# 40    27
# 42    27
# 57    26
# 34    26
# 33    26
# 32    26
# 56    26
# 55    26
# 59    25
# 58    25
# 39    25
# 38    25
# 35    25
# 36    25
# 37    25
# 63    23
# 60    23
# 61    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['bmi'].value_counts()
# Out:
# 32.300    13
# 28.310     9
# 31.350     8
# 30.800     8
# 30.875     8
#           ..
# 20.100     1
# 29.545     1
# 37.900     1
# 25.520     1
# 24.090     1
# Name: bmi, Length: 548, dtype: int64

# %%
df['charges'].value_counts()
# Out:
# 1639.56310     2
# 8825.08600     1
# 43254.41795    1
# 5257.50795     1
# 1980.07000     1
#               ..
# 12269.68865    1
# 6360.99360     1
# 7371.77200     1
# 16420.49455    1
# 34254.05335    1
# Name: charges, Length: 1337, dtype: int64

# %%
plt.figure(figsize=(25,12), dpi=300)
p = sns.barplot(x="age", y="charges", data=df)
plt.show()

# %%
plt.figure(figsize=(10,12), dpi=300)
p = sns.barplot(x="bmi", y="charges", data=df[:15])
plt.show()

# %%
plt.figure(figsize=(25,12), dpi=300)
p = sns.barplot(x="smoker", y="charges", data=df)
plt.show()

# %%
plt.figure(figsize=(25,12), dpi=300)
p = sns.barplot(x="children", y="charges", data=df)
plt.show()

# %%
plt.figure(figsize=(25,12), dpi=300)
p = sns.barplot(x="sex", y="charges", data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df['> 9382'] = df['charges'].apply(lambda x: 'True' if x <= 9382 else 'False')
  
print(df)
# Out:
#       age     sex     bmi  children smoker      charges > 9382
# 0      19  female  27.900         0    yes  16884.92400  False
# 1      18    male  33.770         1     no   1725.55230   True
# 2      28    male  33.000         3     no   4449.46200   True
# 3      33    male  22.705         0     no  21984.47061  False
# 4      32    male  28.880         0     no   3866.85520   True
# ...   ...     ...     ...       ...    ...          ...    ...
# 1333   50    male  30.970         3     no  10600.54830  False
# 1334   18  female  31.920         0     no   2205.98080   True
# 1335   18  female  36.850         0     no   1629.83350   True
# 1336   21  female  25.800         0     no   2007.94500   True
# 1337   61  female  29.070         0    yes  29141.36030  False
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labE = LabelEncoder()

# %%
df['sex'] = labE.fit_transform(df['sex'])
df['smoker'] = labE.fit_transform(df['smoker'])

df['sex'].value_counts()
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   charges   1338 non-null   float64
#  6   > 9382    1338 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 73.3+ KB

# %%
df_target = df['> 9382']
df_selected = df[['age', 'sex', 'children', 'smoker']]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(df_selected,df['> 9382'],test_size=0.30, random_state=101)

# %%
logreg.fit(X_train, Y_train)

Y_pred = logreg.predict(X_test)

logreg.score(X_test, Y_test)
# Out:
# 0.8905472636815921

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_selected, np.ravel(df_target), test_size=0.30, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
print(confusion_matrix(Y_test,predictions))
# Out:
# [[177  22]
#  [ 25 178]]

# %%
print(classification_report(Y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      0.89      0.88       199
#         True       0.89      0.88      0.88       203
#
#     accuracy                           0.88       402
#    macro avg       0.88      0.88      0.88       402
# weighted avg       0.88      0.88      0.88       402

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_selected, np.ravel(df_target), test_size=0.30, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=4)
rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=4)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(Y_test,rfc_pred))
# Out:
# [[178  21]
#  [ 13 190]]

# %%
print(classification_report(Y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.89      0.91       199
#         True       0.90      0.94      0.92       203
#
#     accuracy                           0.92       402
#    macro avg       0.92      0.92      0.92       402
# weighted avg       0.92      0.92      0.92       402

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   charges   1338 non-null   float64
#  6   > 9382    1338 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 73.3+ KB
